# %%
import cv2 as cv

import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
path = '/Users/francobenko/Documents/DataSets/eyes.jpg'

# %%
#Creado de imagenes
img = cv.imread(path)

#Pasando a escala de frises
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
gray = cv.medianBlur(gray,5)

plt.imshow(gray)
plt.show()

# %%
img_out = gray.copy()
circles = cv.HoughCircles(gray,cv.HOUGH_GRADIENT,1.2,minDist=5,param1=95,param2=35,minRadius=10,maxRadius=25)

circles = np.uint16(np.around(circles))
for i in circles[0,:]:
    # Dibujamos el círculo externo
    cv.circle(img_out,(i[0],i[1]),i[2],(0,255,0),2)
    # Dibujamos el centro del círculo
    cv.circle(img_out,(i[0],i[1]),2,(0,0,255),3)
plt.imshow(img_out)
plt.show()

# %%
img_out2 = gray.copy()
circles = cv.HoughCircles(gray,cv.HOUGH_GRADIENT,1.15,minDist=5,param1=55,param2=40,minRadius=10,maxRadius=30)

circles = np.uint16(np.around(circles))
for i in circles[0,:]:
    # Dibujamos el círculo externo
    cv.circle(img_out2,(i[0],i[1]),i[2],(0,255,0),2)
    # Dibujamos el centro del círculo
    cv.circle(img_out2,(i[0],i[1]),2,(0,0,255),3)
plt.imshow(img_out2)
plt.show()

# %%
img_out3= gray.copy()
circles = cv.HoughCircles(gray,cv.HOUGH_GRADIENT,1.5,minDist=35,param1=55,param2=40,minRadius=21,maxRadius=30)

circles = np.uint16(np.around(circles))
for i in circles[0,:]:
    # Dibujamos el círculo externo
    cv.circle(img_out3,(i[0],i[1]),i[2],(0,255,0),2)
    # Dibujamos el centro del círculo
    cv.circle(img_out3,(i[0],i[1]),2,(0,0,255),3)
plt.imshow(img_out3)
plt.show()
